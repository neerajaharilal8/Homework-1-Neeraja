# %% [markdown]
# # Homework 1: Python Basics
#
# **Full Name: Neeraja Harilal
# Student ID: M21139603**
#
# *Course Name: Introduction to Data Science, DATA 101
# Semester: Fall 2026*
#
# Topics Excited to Learn:
# 1. Machine Learning
# 2. Data Visualization/Analysis
# 3. Data Wrangling
#
# <table border="1">
#   <tr>
#     <th>Course Name</th>
#     <th>Credits</th>
#     <th>Day / Time</th>
#     <th>Location</th>
#   </tr>
#   <tr>
#     <td>Calculus I, MATH 181</td>
#     <td>4</td>
#     <td>MON/WED/FRI, 8:00 AM-9:10 AM</td>
#     <td>Takoma Park/Silver Spring Campus, Nunley Student Services Ctr, Room 329</td>
#   </tr>
#   <tr>
#     <td>Introduction to Programming, CMSC140</td>
#     <td>3</td>
#     <td>MON/WED, 11:00 AM-12:15 PM</td>
#     <td>Takoma Park/Silver Spring Campus, Leggett Math & Science, Room 121</td>
#   </tr>
#   <tr>
#     <td>Introduction to Scripting, CMSC135</td>
#     <td>3</td>
#     <td>ON/WED, 1:00 PM-2:15 PM</td>
#     <td>Takoma Park/Silver Spring Campus, Leggett Math & Science, Room 121</td>
#   </tr>
#   <tr>
#     <td>Introduction to Data Science, DATA101</td>
#     <td>3</td>
#     <td>TUE/THURS, 12:30 PM-1:45 PM</td>
#     <td>Rockville Campus, Science Center, Room 362</td>
#   </tr>
#   <tr>
#     <td>Human Growth & Lifespan Development, PSYCH203</td>
#     <td>3</td>
#     <td>ASYNCHRONOUS</td>
#     <td>ASYNCHRONOUS, Distance Learning Campus, Room WEB</td>
#   </tr>
#  </table

# %%
product = "Coffee Mug"
price = 8.99
quantity = 6

price_int = int(price)
print("Data type for converted price is:", type(price_int))

print(f"We have {quantity} units of {product} available at ${price} each.")
# Out:
# Data type for converted price is: <class 'int'>
# We have 6 units of Coffee Mug available at $8.99 each.

# %%
#calculating the total value of mugs by multiplying price & quantity
total_inventory_value = price * quantity
print("Total inventory value is: $", total_inventory_value)

#checking if total inventory value calculated above is over 500 bucks by comparing to get a boolean result
check_value = total_inventory_value > 500
print("Is the total inventory value greater than $500?:", check_value)
# Out:
# Total inventory value is: $ 53.94
# Is the total inventory value greater than $500?: False
